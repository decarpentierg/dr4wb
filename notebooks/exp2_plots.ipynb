# %%
import numpy as np
import matplotlib.pyplot as plt
from experiment2 import *
# Out:
# 2023-01-04 19:29:17.714918: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-01-04 19:29:17.714937: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 6it [00:17,  2.92s/it]
# 6it [00:20,  3.38s/it]
# 6it [00:19,  3.27s/it]

# %%
plt.rcParams.update({'font.size': 22})
plt.figure(figsize=(13, 8))
plot_quality_ratios(SUPPORT_SIZE_VALUES, qr1, label="offset=0")
plot_quality_ratios(SUPPORT_SIZE_VALUES, qr2, label="offset=10")
plot_quality_ratios(SUPPORT_SIZE_VALUES, qr3, label="word vectors")
plt.grid()
plt.xlabel("Support size T")
plt.ylabel("Ratio of solution quality")
plt.legend()
# plt.title("Influence of support size on solution quality")
plt.savefig("figures/experiment_2.png")
plt.show()
