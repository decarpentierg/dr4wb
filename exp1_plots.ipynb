# %%
import numpy as np
import matplotlib.pyplot as plt
from experiment1 import *
# Out:
# 2023-01-06 13:04:20.713831: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-01-06 13:04:20.713846: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 5it [00:00,  6.14it/s]
# 5it [00:00,  5.55it/s]
# 5it [00:00,  6.34it/s]

# %%
plt.rcParams.update({'font.size': 22})
plt.figure(figsize=(13, 8))
plot_quality_ratios(M_VALUES, qr1, label="offset=0")
plot_quality_ratios(M_VALUES, qr2, label="offset=10")
plot_quality_ratios(M_VALUES, qr3, label="word vectors")
plt.grid()
plt.xlabel("Projected dimension m")
plt.ylabel("Ratio of solution quality")
plt.legend()
# plt.title("Influence of projected dimension on solution quality")
plt.savefig("figures/experiment_1.png")
plt.show()
