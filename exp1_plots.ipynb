# %%
import numpy as np
import matplotlib.pyplot as plt
from experiment1 import *
# Out:
# 2022-12-27 18:32:37.449799: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-27 18:32:37.449817: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 5it [00:00,  6.94it/s]
# 5it [00:00,  6.89it/s]

# %%
# def plot_quality_ratios(m_values, quality_ratios, label=""):
#     y_mean = np.mean(quality_ratios, axis=1)
#     y_std= np.std(quality_ratios, axis=1)
#     y_err = 2 * y_std / np.sqrt(quality_ratios.shape[1])
#     plt.plot(m_values, np.log10(y_mean - 1), label=label)
#     plt.fill_between(m_values, np.log10(y_mean - y_err - 1), np.log10(y_mean + y_err - 1), alpha=0.3)

# %%
plt.rcParams.update({'font.size': 22})
plt.figure(figsize=(13, 8))
plot_quality_ratios(M_VALUES, qr1, label="offset=0")
plot_quality_ratios(M_VALUES, qr2, label="offset=10")
plt.grid()
plt.xlabel("Projection dimension m")
plt.ylabel("Ratio of solution quality")
plt.legend()
plt.title("Experiment 1")
plt.show()
