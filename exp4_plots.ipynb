# %%
import numpy as np
import matplotlib.pyplot as plt
from experiment4 import *
# Out:
# 2023-01-04 19:09:30.446228: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-01-04 19:09:30.446245: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 5it [00:01,  4.72it/s]
# 5it [00:01,  3.80it/s]
# 5it [00:01,  4.40it/s]

# %%
plt.rcParams.update({'font.size': 22})
plt.figure(figsize=(13, 8))
plot_quality_ratios(DIM_VALUES, qr1, label="offset=0")
plot_quality_ratios(DIM_VALUES, qr2, label="offset=10")
plot_quality_ratios(DIM_VALUES, qr3, label="word vectors")
plt.grid()
plt.xlabel("Original dimension d")
plt.ylabel("Ratio of solution quality")
plt.legend()
plt.title("Influence of original dimension on solution quality")
plt.savefig("figures/experiment_4.png")
plt.show()
