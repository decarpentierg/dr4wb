# %%
import numpy as np
import matplotlib.pyplot as plt
from experiment3 import *
# Out:
# 2023-01-06 13:04:38.581119: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-01-06 13:04:38.581137: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# %matplotlib inline

# %%
for m in [3, 10, 30, 100, 300, 1000]:
    plot(m)
