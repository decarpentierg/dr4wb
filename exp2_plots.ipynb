# %%
import numpy as np
import matplotlib.pyplot as plt
from experiment2 import *
# Out:
# 2023-01-04 11:35:24.064269: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-01-04 11:35:24.064284: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 6it [00:16,  2.82s/it]
# 6it [00:18,  3.11s/it]
# 6it [00:19,  3.21s/it]

# %%
plt.rcParams.update({'font.size': 22})
plt.figure(figsize=(13, 8))
plot_quality_ratios(SUPPORT_SIZE_VALUES, qr1, label="offset=0")
plot_quality_ratios(SUPPORT_SIZE_VALUES, qr2, label="offset=10")
plot_quality_ratios(SUPPORT_SIZE_VALUES, qr3, label="word vectors")
plt.grid()
plt.xlabel("Support size n'")
plt.ylabel("Ratio of solution quality")
plt.legend()
plt.title("Experiment 2")
plt.savefig("figures/experiment_2.png")
plt.show()
